# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a686f01b-c34a-4574-9b8d-719cbd996759" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a686f01b-c34a-4574-9b8d-719cbd996759">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('Book1.csv')   # same name use karo jo upload hua tha
df.head()
# Out:
#     Order_ID        Date Customer_ID Product_Category  Unnamed: 4  \
# 0  ORD100000  25-01-2025    CUST2796   Home & Kitchen         NaN
# 1  ORD100001  28-08-2025    CUST9669           Beauty         NaN
# 2  ORD100002  27-02-2025    CUST5808      Electronics         NaN
# 3  ORD100003  24-02-2025    CUST5889      Electronics         NaN
# 4  ORD100004  15-06-2025    CUST9005         Clothing         NaN
#
#    Product_Name  Quantity  Unit_Price_INR  Total_Sales_INR    Payment_Method  \
# 0  Cookware Set         2        25574.41         51148.82       Credit Card
# 1    Hair Dryer         1        19361.41         19361.41        Debit Card
# 2        Tablet         3        38476.22        115428.66  Cash on Delivery
# 3    Headphones         5        38145.72        190728.60       Credit Card
# 4         Saree         5        45940.98        229704.90               UPI
#
#   Delivery_Status  Review_Rating         Review_Text      State Country
# ...

# %%
from google.colab import files
files.download('Book1.csv.ipynb')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1574128286.py in <cell line: 0>()
#       1 from google.colab import files
# ----> 2 files.download('Book1.csv.ipynb')
#       3
#       4
#       5
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: Book1.csv.ipynb

# %% [markdown]
# # New Section

# %%
# !ls
# Out:
# Book1.csv  sample_data
